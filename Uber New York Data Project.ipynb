# %% [markdown]
# # Uber and Taxi Analysis in NYC

# %% [markdown]
# In the dynamic landscape of urban transportation, the emergence of ride-sharing services, notably Uber, has significantly reshaped the way people navigate through cities. A series of articles have emphasized the impact of Uber on the iconic streets of New York City. This project embarks on a comprehensive exploration, not only delving into the transformative impact of Uber's millions of rides but also incorporating the traditional taxi landscape into the narrative.
#
# Utilizing robust methodologies of Exploratory Data Analysis (EDA) and the transformative potential of Extract, Transform, Load (ETL) processes, the main objective is to uncover intricate trends and patterns in both Uber and NYC's taxi influence. By examining the coexistence of these two transportation modes, the objective is to provide a nuanced understanding of their collective influence on New York City's intricate transportation network.
#
# Beyond quantifying shifts in pickup rates, this analysis seeks to shed light on the intricate nuances that shape the urban mobility landscape. By discerning the intricate interplay of Uber and traditional taxis within the city, the goal is to unveil the multifaceted effects these services have on New York City's transportation ecosystem. This holistic approach will contribute to a more comprehensive and nuanced understanding of the evolving dynamics between ride-sharing and traditional taxi services in  New York City.

# %% [markdown]
# # Background, Data and Goal

# %% [markdown]
# The articles [Uber Is Serving New York’s Outer Boroughs More Than Taxis Are](https://fivethirtyeight.com/features/uber-is-serving-new-yorks-outer-boroughs-more-than-taxis-are/),[Public Transit Should Be Uber’s New Best Friend](https://fivethirtyeight.com/features/public-transit-should-be-ubers-new-best-friend/),[Uber Is Taking Millions Of Manhattan Rides Away From Taxis](https://fivethirtyeight.com/features/uber-is-taking-millions-of-manhattan-rides-away-from-taxis/), and [Is Uber Making NYC Rush-Hour Traffic Worse?](https://fivethirtyeight.com/features/is-uber-making-nyc-rush-hour-traffic-worse/),investigates Uber's significant growth and its potential contribution to the city's traffic congestion.
#
# These articles delve into the complex relationship between Uber's expansion, its increasing number of pickups, and the implications for congestion levels in different areas of New York City. Through data analysis and exploration, these articles shed light on how Uber's presence in various boroughs, particularly in Manhattan, has impacted traffic patterns, especially during peak hours.
#
# The investigation aims to utilize data-driven analysis similar to the approaches presented in these articles to further understand the dynamics of Uber's growth and its potential role in influencing traffic congestion within the city.

# %% [markdown]
# ## Uber Data
# The [data](https://github.com/fivethirtyeight/uber-tlc-foil-response/blob/master/README.md) comprises six different files for the period of April to September 2014,respectively. Each file contains the following columns:
#
# ### Uber Pickups Dataset Columns (April-September 2014)
#
# | Header       | Definition                              |
# |--------------|-----------------------------------------|
# | Date/Time    | The timestamp of the Uber pickup        |
# | Lat          | Latitude of the Uber pickup location    |
# | Lon          | Longitude of the Uber pickup location   |
# | Base         | TLC base company code affiliated        |
#
# Additionally, there's a file named `uber-raw-data-janjune-15.csv.zip`, which, once unzipped, provides data with the following columns:
#
# ### Uber Raw Data Columns (January-June 2015)
#
# | Header              | Definition                                      |
# |---------------------|-------------------------------------------------|
# | Dispatching_base_num| TLC base company code of the dispatching base    |
# | Pickup_date         | Timestamp of the Uber pickup                     |
# | Affiliated_base_num | TLC base company code affiliated with the pickup |
# | locationID          | Pickup location ID affiliated with the pickup
#
# The TLC base company codes correspond to the following Uber bases:
# | Base Code | Base Name    |
# |-----------|--------------|
# | B02512    | Unter        |
# | B02598    | Hinter       |
# | B02617    | Weiter       |
# | B02682    | Schmecken    |
# | B02764    | Danach-NY    |
# | B02765    | Grun         |
# | B02835    | Dreist       |
# | B02836    | Drinnen      |
#
# Lastly, there's a file named `Uber-Jan-Feb-FOIL.csv`, which once unzipped, provides data with the following columns:
#
# ###  Uber aggregated trip statistics (January-Febuary 2015)
# | Column Name           | Description                                                   |
# |-----------------------|---------------------------------------------------------------|
# | dispatching_base_number | TLC base company code of the dispatching base |
# | date                  | Date corresponding to the data entry, indicating the time of record or collection. |
# | active_vehicles       | Count of Uber vehicles actively in operation or available for service on the recorded date. |
# | trips                 | Total number of trips completed or undertaken by Uber vehicles affiliated with the specified TLC base on the given date. |
#
# ## Taxi Data
#
# The [data](https://data.cityofnewyork.us/browse?Data-Collection_Data-Collection=TLC%20Trip%20Data&sortBy=alpha) represents information from a single file covering the timeframe from April to September 2014. The data has undergone filtering and extraction processes before being exported.
#
# ### NYC Taxi Pickups Dataset Columns (April-September 2014)
#
# | Column                  | Definition                                   |
# |-------------------------|----------------------------------------------|
# | vendorid                | A code indicating the TPEP provider that provided the record.                                       |
# | pickup_datetime         | The date and time when the meter was engaged.                                                        |
# | dropoff_datetime        | The date and time when the meter was disengaged.                                                    |
# | Store_and_fwd_flag      | This flag indicates whether the trip record was held in vehicle memory before sending to the vendor. |
# | rate_code               | The final rate code in effect at the end of the trip.                                                |
# | Pickup_longitude        | Longitude of the pickup location.                                                                     |
# | Pickup_latitude         | Latitude of the pickup location.                                                                      |
# | Dropoff_longitude       | Longitude of the dropoff location.                                                                    |
# | Dropoff_latitude        | Latitude of the dropoff location.                                                                     |
# | Passenger_count         | The number of passengers in the vehicle.                                                            |
# | Trip_distance           | The elapsed trip distance in miles reported by the taximeter.                                       |
# | Fare_amount             | The time-and-distance fare calculated by the meter.                                                 |
# | Extra                   | Miscellaneous extras and surcharges.                                                                |
# | MTA_tax                 | Tax that is automatically triggered based on the metered rate in use.                               |
# | Tip_amount              | Tip amount – This field is automatically populated for credit card tips. Cash tips are not included.|
# | Tolls_amount            | Total amount of all tolls paid in the trip.                                                         |
# | Ehail_fee               | Electronic Hail Fee (if applicable).                                                                |
# | Improvement_surcharge   | Improvement surcharge assessed trips at the flag drop. The improvement surcharge began being levied in 2015.|
# | Total_amount            | The total amount charged to passengers. Does not include cash tips.                                  |
# | Payment_type            | A numeric code signifying how the passenger paid for the trip.                                       |
# | Trip_type               | A code indicating the type of trip (e.g., street-hail, dispatch).                                   |
#
# Additionally, there's a file named `2015_Green_Taxi_Trip_Dataq1_q2`, which, once unzipped, provides data with the same columns listed above respectively.
#
#
# # Project Goal
# The primary aim of this project is to:
#
#
# 1. Explore temporal and spatial patterns in Uber and Taxi pickups, investigating correlations across different times of the hour, weekday, and month to discern alignment or divergence between the two modes of transportation.
# 2. Visualize Uber's growth trends and assess their potential impact on traffic dynamics in diverse areas of New York City.
# 3. Conduct a comprehensive comparative analysis between Uber and the traditional taxi ecosystem in NYC.
# 4. Derive actionable insights and recommendations for urban transportation based on the findings from the analysis of Uber and Taxi datasets.

# %% [markdown]
# # Exploring the Data (Uber Raw Data  (January-June 2015))

# %%
# Import libraries

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###  uber-raw-data-janjune-15.csv.zip

# %%
#Reading in the data

df = pd.read_csv('uber-raw-data-janjune-15_sample.csv')

# %%
# Exploring the dataframe from jan-june 15

df.head()
# Out:
#   Dispatching_base_num          Pickup_date Affiliated_base_num  locationID
# 0               B02617  2015-05-02 21:43:00              B02764         237
# 1               B02682  2015-01-20 19:52:59              B02682         231
# 2               B02617  2015-03-19 20:26:00              B02617         161
# 3               B02764  2015-04-10 17:38:00              B02764         107
# 4               B02764  2015-03-23 07:03:00              B00111         140

# %%
# Checking how many rows,columns and data types are within the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Dispatching_base_num  100000 non-null  object
#  1   Pickup_date           100000 non-null  object
#  2   Affiliated_base_num   98882 non-null   object
#  3   locationID            100000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 3.1+ MB

# %% [markdown]
# ### Data Cleansing (Uber Raw Data (January-June 2015))

# %%
# Seeing if there is any duplicated values within the dataset

df.duplicated().sum()
# Out:
# 54

# %%
# Dropping all duplicated values

df = df.drop_duplicates()

# %%
# Updated values for duplicated values

df.duplicated().sum()
# Out:
# 0

# %%
# Seeing if there is any relevant null values within the dataset 

df.isnull().sum()
# Out:
# Dispatching_base_num       0
# Pickup_date                0
# Affiliated_base_num     1116
# locationID                 0
# dtype: int64

# %%
# Changing Pickup_date object/string type into datetime type

df['Pickup_date'] = pd.to_datetime(df['Pickup_date'])

# %%
# Updated type for Pickup_date

df.dtypes
# Out:
# Dispatching_base_num            object
# Pickup_date             datetime64[ns]
# Affiliated_base_num             object
# locationID                       int64
# dtype: object

# %%
# Creating new column for 'Pickup_month', converting it to month name
# Creating new column for 'Pickup_day', converting it to day name
# Creating new column for 'Pickup_hour', converting it to hour format
# Creating new column for 'Pickup_minute', converting it to minute format

df['month'] = df['Pickup_date'].dt.month_name()
df['weekday'] = df['Pickup_date'].dt.day_name()
df['hours'] = df['Pickup_date'].dt.hour
df['minutes'] = df['Pickup_date'].dt.minute

# %%
# Updated column for Pickup_month,Pickup_day,Pickup_hour, and Pickup_minute

df.head()
# Out:
#   Dispatching_base_num         Pickup_date Affiliated_base_num  locationID  \
# 0               B02617 2015-05-02 21:43:00              B02764         237
# 1               B02682 2015-01-20 19:52:59              B02682         231
# 2               B02617 2015-03-19 20:26:00              B02617         161
# 3               B02764 2015-04-10 17:38:00              B02764         107
# 4               B02764 2015-03-23 07:03:00              B00111         140
#
#      month   weekday  hours  minutes
# 0      May  Saturday     21       43
# 1  January   Tuesday     19       52
# 2    March  Thursday     20       26
# 3    April    Friday     17       38
# 4    March    Monday      7        3

# %%
# Creating a crosstab to display frequencies

pivot = pd.crosstab(index = df['month'], columns = df['weekday'])

# %%
# Updated crosstab

pivot
# Out:
# weekday   Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# month
# April       2365    1833      2508    2052      2823     1880       2521
# February    2655    1970      2550    2183      2396     2129       2013
# January     2508    1353      2745    1651      2378     1444       1740
# June        2793    2848      3037    2485      2767     3187       2503
# March       2465    2115      2522    2379      2093     2388       2007
# May         3262    1865      3519    2944      2627     2115       2328

# %%
# Redefining/Reindexing order of months & weekdays for organization/readability purposes

month_order = ['January', 'February', 'March' , 'April' , "May" , 'June'] 
month_order2 = ['April', 'May', 'June', 'July', 'August', 'September']
weekday_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']  

pivot_sorted = pivot.reindex(index=month_order).reindex(columns=weekday_order)

# %%
# Updated crosstab for organization/readability

pivot_sorted
# Out:
# weekday   Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# month
# January     1353     1444       1740      2378    2508      2745    1651
# February    1970     2129       2013      2396    2655      2550    2183
# March       2115     2388       2007      2093    2465      2522    2379
# April       1833     1880       2521      2823    2365      2508    2052
# May         1865     2115       2328      2627    3262      3519    2944
# June        2848     3187       2503      2767    2793      3037    2485

# %%
# Creating groupby for weekday & hour of uber pickups(size)

weekday_hours = df.groupby(['weekday','hours'], as_index = False).size()

# %%
# Updated groupby for weekday,hours of uber pickups represented by 'size'

weekday_hours
# Out:
#        weekday  hours  size
# 0       Friday      0   581
# 1       Friday      1   333
# 2       Friday      2   197
# 3       Friday      3   138
# 4       Friday      4   161
# ..         ...    ...   ...
# 163  Wednesday     19  1044
# 164  Wednesday     20   897
# 165  Wednesday     21   949
# 166  Wednesday     22   900
# 167  Wednesday     23   669
#
# [168 rows x 3 columns]

# %% [markdown]
# ### Exploring and Transforming Uber-Jan-Feb-FOIL.csv (Uber aggregated trip statistics (January-Febuary 2015))

# %%
# Reading in data of base number

df_base_num = pd.read_csv('Uber-Jan-Feb-FOIL.csv')

# %%
# Exploring the data

df_base_num.head()
# Out:
#   dispatching_base_number      date  active_vehicles  trips
# 0                  B02512  1/1/2015              190   1132
# 1                  B02765  1/1/2015              225   1765
# 2                  B02764  1/1/2015             3427  29421
# 3                  B02682  1/1/2015              945   7679
# 4                  B02617  1/1/2015             1228   9537

# %%
df_base_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dispatching_base_number  354 non-null    object
#  1   date                     354 non-null    object
#  2   active_vehicles          354 non-null    int64
#  3   trips                    354 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 11.2+ KB

# %%
# Seeing if there is any relevant null values within the dataset

df_base_num.isnull().sum()
# Out:
# dispatching_base_number    0
# date                       0
# active_vehicles            0
# trips                      0
# dtype: int64

# %%
# Seeing if there is any duplicated values within the dataset

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Reading and Combining every dataset from April-September 2014 (Q2-Q3)

# %%
# Reading in every file then combining/concatenating it into a combined dataframe. 

df_apr = pd.read_csv('uber-raw-data-apr14.csv')
df_may = pd.read_csv('uber-raw-data-may14.csv')
df_jun = pd.read_csv('uber-raw-data-jun14.csv')
df_jul = pd.read_csv('uber-raw-data-jul14.csv')
df_aug = pd.read_csv('uber-raw-data-aug14.csv')
df_sep = pd.read_csv('uber-raw-data-sep14.csv')

combined_df = pd.concat([df_apr, df_may, df_jun, df_jul, df_aug, df_sep], ignore_index = True)

# %%
# Exploring the combined data

combined_df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4534327 entries, 0 to 4534326
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Date/Time  object
#  1   Lat        float64
#  2   Lon        float64
#  3   Base       object
# dtypes: float64(2), object(2)
# memory usage: 138.4+ MB

# %% [markdown]
# ### Cleaning and organizing combined_df dataframe

# %%
# Seeing if there is any duplicated values within the dataset

combined_df.duplicated().sum()
# Out:
# 82581

# %%
# Dropping all duplicated values within the dataset

combined_df = combined_df.drop_duplicates()

# %%
# Updated duplicated values

combined_df.duplicated().sum()
# Out:
# 0

# %%
# Seeing if there is any relevant null values within the dataset

combined_df.isnull().sum()
# Out:
# Date/Time    0
# Lat          0
# Lon          0
# Base         0
# dtype: int64

# %%
# Changing Date/Time object/string type into datetime type & creating day/hour 

combined_df['Date/Time'] = pd.to_datetime(combined_df['Date/Time'],format ='%m/%d/%Y %H:%M:%S')

combined_df['month'] = combined_df['Date/Time'].dt.month_name()
combined_df['day'] = combined_df['Date/Time'].dt.day
combined_df['hour'] = combined_df['Date/Time'].dt.hour
combined_df['weekday'] = combined_df['Date/Time'].dt.day_name()

# %%
# Updated values for combined_df

combined_df
# Out:
#                   Date/Time      Lat      Lon    Base      month  day  hour  \
# 0       2014-04-01 00:11:00  40.7690 -73.9549  B02512      April    1     0
# 1       2014-04-01 00:17:00  40.7267 -74.0345  B02512      April    1     0
# 2       2014-04-01 00:21:00  40.7316 -73.9873  B02512      April    1     0
# 3       2014-04-01 00:28:00  40.7588 -73.9776  B02512      April    1     0
# 4       2014-04-01 00:33:00  40.7594 -73.9722  B02512      April    1     0
# ...                     ...      ...      ...     ...        ...  ...   ...
# 4534322 2014-09-30 22:57:00  40.7668 -73.9845  B02764  September   30    22
# 4534323 2014-09-30 22:57:00  40.6911 -74.1773  B02764  September   30    22
# 4534324 2014-09-30 22:58:00  40.8519 -73.9319  B02764  September   30    22
# 4534325 2014-09-30 22:58:00  40.7081 -74.0066  B02764  September   30    22
# 4534326 2014-09-30 22:58:00  40.7140 -73.9496  B02764  September   30    22
#
#          weekday
# 0        Tuesday
# 1        Tuesday
# ...

# %%
# Creating a crosstab to display frequencies

pivot2 = pd.crosstab(index = combined_df['month'], columns = combined_df['weekday'])

# %%
pivot2
# Out:
# weekday    Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# month
# April       88985   60075     76152   50524     83954    89957     107120
# August     145719   90011    129668  108168    121655   105160     113012
# July       100987   91672     88626   74976    145791   134968     144949
# June       103352   93261     80084   78369    113439    86706      97947
# May        131880   62915    101583   55244    126919    75537      88282
# September  156609  134199    158081  113877    149614   159425     132294

# %%
# Updated crosstab for organization/readability

pivot_sorted2 = pivot2.reindex(index=month_order2).reindex(columns=weekday_order)

# %%
pivot_sorted2
# Out:
# weekday    Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# month
# April       60075    89957     107120     83954   88985     76152   50524
# May         62915    75537      88282    126919  131880    101583   55244
# June        93261    86706      97947    113439  103352     80084   78369
# July        91672   134968     144949    145791  100987     88626   74976
# August      90011   105160     113012    121655  145719    129668  108168
# September  134199   159425     132294    149614  156609    158081  113877

# %%
# Creating groupby for weekday & hour of uber pickups(size)

weekday_hours2 = combined_df.groupby(['weekday','hour'], as_index = False).size()

# %%
# Updated groupby for weekday,hours of uber pickups represented by 'size'

weekday_hours2
# Out:
#        weekday  hour   size
# 0       Friday     0  13447
# 1       Friday     1   8002
# 2       Friday     2   5232
# 3       Friday     3   6788
# 4       Friday     4   8641
# ..         ...   ...    ...
# 163  Wednesday    19  46096
# 164  Wednesday    20  46875
# 165  Wednesday    21  43754
# 166  Wednesday    22  32222
# 167  Wednesday    23  17803
#
# [168 rows x 3 columns]

# %% [markdown]
# # Taxi data

# %% [markdown]
# ### Exploring and Transforming 2015_Green_Taxi_Trip_Dataq1_q2.csv (NYC taxi's aggregated trip statistics (January-June 2015)) (Q1-Q2)

# %%
#Reading in the data

taxi = pd.read_csv('2015_Green_Taxi_Trip_Dataq1_q2.csv',low_memory=False)

# %%
# Exploring the dataframe from jan-febuary

taxi.head()
# Out:
#    vendorid         pickup_datetime        dropoff_datetime  \
# 0         2  01/01/2015 12:00:00 AM  01/01/2015 12:00:00 AM
# 1         1  01/01/2015 12:00:02 AM  01/01/2015 12:16:25 AM
# 2         2  01/01/2015 12:00:03 AM  01/01/2015 12:12:06 AM
# 3         2  01/01/2015 12:00:03 AM  01/01/2015 12:17:00 AM
# 4         2  01/01/2015 12:00:10 AM  01/01/2015 12:06:44 AM
#
#   Store_and_fwd_flag  rate_code  Pickup_longitude  Pickup_latitude  \
# 0                  N          1        -73.961418        40.806293
# 1                  N          1        -73.951454        40.824905
# 2                  N          1        -73.930908        40.694630
# 3                  N          1        -73.959808        40.813663
# 4                  N          1        -73.961418        40.714340
#
#    Dropoff_longitude  Dropoff_latitude  Passenger_count  ...  Fare_amount  \
# 0         -73.948746         40.823627                1  ...          6.5
# ...

# %%
# Checking how many rows,columns and data types are within the dataframe

taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9853035 entries, 0 to 9853034
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   vendorid               int64
#  1   pickup_datetime        object
#  2   dropoff_datetime       object
#  3   Store_and_fwd_flag     object
#  4   rate_code              int64
#  5   Pickup_longitude       float64
#  6   Pickup_latitude        float64
#  7   Dropoff_longitude      float64
#  8   Dropoff_latitude       float64
#  9   Passenger_count        int64
#  10  Trip_distance          float64
#  11  Fare_amount            float64
#  12  Extra                  float64
#  13  MTA_tax                float64
#  14  Tip_amount             float64
#  15  Tolls_amount           float64
#  16  Ehail_fee              float64
#  17  Improvement_surcharge  float64
#  18  Total_amount           float64
#  19  Payment_type           int64
#  20  Trip_type              float64
# ...

# %%
# Changing pickup_datetime object/string type into datetime type

taxi['pickup_datetime'] = pd.to_datetime(taxi['pickup_datetime'])

# Creating new column for 'taxi_month', converting it to month name
# Creating new column for 'taxi_day', converting it to day name
# Creating new column for 'taxi_hour', converting it to hour format
# Creating new column for 'taxi_minute', converting it to minute format

taxi['taxi_month'] = taxi['pickup_datetime'].dt.month_name()
taxi['taxi_day'] = taxi['pickup_datetime'].dt.day
taxi['taxi_hour'] = taxi['pickup_datetime'].dt.hour
taxi['taxi_weekday'] = taxi['pickup_datetime'].dt.day_name()

# %%
taxi.head()
# Out:
#    vendorid     pickup_datetime        dropoff_datetime Store_and_fwd_flag  \
# 0         2 2015-01-01 00:00:00  01/01/2015 12:00:00 AM                  N
# 1         1 2015-01-01 00:00:02  01/01/2015 12:16:25 AM                  N
# 2         2 2015-01-01 00:00:03  01/01/2015 12:12:06 AM                  N
# 3         2 2015-01-01 00:00:03  01/01/2015 12:17:00 AM                  N
# 4         2 2015-01-01 00:00:10  01/01/2015 12:06:44 AM                  N
#
#    rate_code  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0          1        -73.961418        40.806293         -73.948746
# 1          1        -73.951454        40.824905         -73.895561
# 2          1        -73.930908        40.694630         -73.956932
# 3          1        -73.959808        40.813663         -73.882378
# 4          1        -73.961418        40.714340         -73.961357
#
#    Dropoff_latitude  Passenger_count  ...  Tolls_amount  Ehail_fee  \
# ...

# %%
# Seeing if there is any duplicated values within the dataset

taxi.duplicated().sum()
# Out:
# 129

# %%
# Dropping all duplicated values

taxi = taxi.drop_duplicates()

# %%
# Seeing if there is any relevant null values within the dataset 

taxi.isnull().sum()
# Out:
# vendorid                       0
# pickup_datetime                0
# dropoff_datetime               0
# Store_and_fwd_flag             0
# rate_code                      0
# Pickup_longitude               0
# Pickup_latitude                0
# Dropoff_longitude              0
# Dropoff_latitude               0
# Passenger_count                0
# Trip_distance                  0
# Fare_amount                    0
# Extra                          0
# MTA_tax                        0
# Tip_amount                     0
# Tolls_amount                   0
# Ehail_fee                9852906
# Improvement_surcharge          0
# Total_amount                   0
# Payment_type                   0
# Trip_type                     17
# taxi_month                     0
# taxi_day                       0
# taxi_hour                      0
# taxi_weekday                   0
# dtype: int64

# %%
# Creating a crosstab to display frequencies

taxi_pivot = pd.crosstab(index = taxi['taxi_month'], columns = taxi['taxi_weekday'])

# %%
# Updated crosstab

taxi_pivot
# Out:
# taxi_weekday  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# taxi_month
# April         245476  179219    292402  246096    270079   180725     250397
# February      265631  185659    283581  232721    225575   185963     195697
# January       274718  148436    312262  199979    252921   142195     177884
# June          244352  229543    285003  242646    209611   188790     195923
# March         253374  227722    290068  295078    202562   249694     204076
# May           315683  182519    368809  313071    216772   187381     202613

# %%
# Redefining/Reindexing order of months & weekdays for organization/readability purposes

taxi_pivot_sorted = taxi_pivot.reindex(index=month_order).reindex(columns=weekday_order)

# %%
# Updated crosstab

taxi_pivot_sorted
# Out:
# taxi_weekday  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  Sunday
# taxi_month
# January       148436   142195     177884    252921  274718    312262  199979
# February      185659   185963     195697    225575  265631    283581  232721
# March         227722   249694     204076    202562  253374    290068  295078
# April         179219   180725     250397    270079  245476    292402  246096
# May           182519   187381     202613    216772  315683    368809  313071
# June          229543   188790     195923    209611  244352    285003  242646

# %%
# Creating groupby for weekday & hour of taxi pickups(size)

taxi_weekday_hours = taxi.groupby(['taxi_weekday','taxi_hour'], as_index = False).size()

# %%
# Updated groupby for weekday,hours of uber pickups represented by 'size'

taxi_weekday_hours
# Out:
#     taxi_weekday  taxi_hour   size
# 0         Friday          0  57446
# 1         Friday          1  40950
# 2         Friday          2  27377
# 3         Friday          3  19248
# 4         Friday          4  16235
# ..           ...        ...    ...
# 163    Wednesday         19  88807
# 164    Wednesday         20  81138
# 165    Wednesday         21  73869
# 166    Wednesday         22  67353
# 167    Wednesday         23  58266
#
# [168 rows x 3 columns]

# %% [markdown]
# ### Exploring and Transforming 2014_Green_Taxi_Trip_Dataq2_q3.csv (NYC taxi's aggregated trip statistics (January-June 2015)) (Q2-Q3)

# %%
#Reading in the data

taxi_two = pd.read_csv('2014_Green_Taxi_Trip_Dataq2_q3.csv',low_memory=False)

# %%
# Exploring the dataframe from jan-febuary

taxi_two.head()
# Out:
#    vendorid         pickup_datetime        dropoff_datetime  \
# 0         2  04/01/2014 12:00:00 AM  04/01/2014 10:43:03 AM
# 1         2  04/01/2014 12:00:00 AM  04/01/2014 05:26:38 AM
# 2         2  04/01/2014 12:00:00 AM  04/01/2014 10:35:43 AM
# 3         2  04/01/2014 12:00:00 AM  04/01/2014 10:30:14 AM
# 4         2  04/01/2014 12:00:00 AM  04/01/2014 10:59:14 AM
#
#   Store_and_fwd_flag  rate_code  Pickup_longitude  Pickup_latitude  \
# 0                  N          1               0.0              0.0
# 1                  N          1               0.0              0.0
# 2                  N          1               0.0              0.0
# 3                  N          1               0.0              0.0
# 4                  N          1               0.0              0.0
#
#    Dropoff_longitude  Dropoff_latitude  Passenger_count  Trip_distance  \
# 0         -73.946358         40.806702                1           1.57
# ...

# %%
# Checking how many rows,columns and data types are within the dataframe

taxi_two.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8010497 entries, 0 to 8010496
# Data columns (total 20 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   vendorid            int64
#  1   pickup_datetime     object
#  2   dropoff_datetime    object
#  3   Store_and_fwd_flag  object
#  4   rate_code           int64
#  5   Pickup_longitude    float64
#  6   Pickup_latitude     float64
#  7   Dropoff_longitude   float64
#  8   Dropoff_latitude    float64
#  9   Passenger_count     int64
#  10  Trip_distance       float64
#  11  Fare_amount         float64
#  12  Extra               float64
#  13  MTA_tax             float64
#  14  Tip_amount          float64
#  15  Tolls_amount        float64
#  16  Ehail_fee           float64
#  17  Total_amount        float64
#  18  Payment_type        int64
#  19  Trip_type           float64
# dtypes: float64(13), int64(4), object(3)
# memory usage: 1.2+ GB

# %%
# Changing pickup_datetime object/string type into datetime type

taxi_two['pickup_datetime'] = pd.to_datetime(taxi_two['pickup_datetime'])

# Creating new column for 'taxi_month', converting it to month name
# Creating new column for 'taxi_day', converting it to day name
# Creating new column for 'taxi_hour', converting it to hour format
# Creating new column for 'taxi_minute', converting it to minute format

taxi_two['taxi_two_month'] = taxi_two['pickup_datetime'].dt.month_name()
taxi_two['taxi_two_day'] = taxi_two['pickup_datetime'].dt.day
taxi_two['taxi_two_hour'] = taxi_two['pickup_datetime'].dt.hour
taxi_two['taxi_two_weekday'] = taxi_two['pickup_datetime'].dt.day_name()

# %%
taxi_two.head()
# Out:
#    vendorid pickup_datetime        dropoff_datetime Store_and_fwd_flag  \
# 0         2      2014-04-01  04/01/2014 10:43:03 AM                  N
# 1         2      2014-04-01  04/01/2014 05:26:38 AM                  N
# 2         2      2014-04-01  04/01/2014 10:35:43 AM                  N
# 3         2      2014-04-01  04/01/2014 10:30:14 AM                  N
# 4         2      2014-04-01  04/01/2014 10:59:14 AM                  N
#
#    rate_code  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0          1               0.0              0.0         -73.946358
# 1          1               0.0              0.0         -73.872177
# 2          1               0.0              0.0         -73.994530
# 3          1               0.0              0.0           0.000000
# 4          1               0.0              0.0           0.000000
#
#    Dropoff_latitude  Passenger_count  ...  Tip_amount  Tolls_amount  \
# ...

# %%
# Seeing if there is any duplicated values within the dataset

taxi_two.duplicated().sum()
# Out:
# 148

# %%
# Dropping all duplicated values

taxi_two = taxi_two.drop_duplicates()

# %%
# Seeing if there is any relevant null values within the dataset 

taxi_two.isnull().sum()
# Out:
# vendorid                    0
# pickup_datetime             0
# dropoff_datetime            0
# Store_and_fwd_flag          0
# rate_code                   0
# Pickup_longitude            0
# Pickup_latitude             0
# Dropoff_longitude           0
# Dropoff_latitude            0
# Passenger_count             0
# Trip_distance               0
# Fare_amount                 0
# Extra                       0
# MTA_tax                     0
# Tip_amount                  0
# Tolls_amount                0
# Ehail_fee             8010349
# Total_amount                0
# Payment_type                0
# Trip_type               84118
# taxi_two_month              0
# taxi_two_day                0
# taxi_two_hour               0
# taxi_two_weekday            0
# dtype: int64

# %%
# Creating a crosstab to display frequencies

taxi_two_pivot = pd.crosstab(index = taxi_two['taxi_two_month'], columns = taxi_two['taxi_two_weekday'])

# %%
# Updated crosstab

taxi_two_pivot
# Out:
# taxi_two_weekday  Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# taxi_two_month
# April             196587  141430    227627  187817    168074   184920
# August            240649  137203    276785  235976    162857   140261
# July              177710  133684    207176  178185    205274   180570
# June              200300  179299    230395  240743    174442   150568
# May               263354  145769    291020  195694    217609   148050
# September         203705  185340    245412  202848    173554   152989
#
# taxi_two_weekday  Wednesday
# taxi_two_month
# April                202700
# August               151065
# July                 191374
# June                 162012
# May                  160007
# September            159315

# %%
# Redefining/Reindexing order of months & weekdays for organization/readability purposes

taxi_two_pivot_sorted = taxi_two_pivot.reindex(index=month_order2).reindex(columns=weekday_order)

# %%
# Updated crosstab

taxi_two_pivot_sorted
# Out:
# taxi_two_weekday  Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  \
# taxi_two_month
# April             141430   184920     202700    168074  196587    227627
# May               145769   148050     160007    217609  263354    291020
# June              179299   150568     162012    174442  200300    230395
# July              133684   180570     191374    205274  177710    207176
# August            137203   140261     151065    162857  240649    276785
# September         185340   152989     159315    173554  203705    245412
#
# taxi_two_weekday  Sunday
# taxi_two_month
# April             187817
# May               195694
# June              240743
# July              178185
# August            235976
# September         202848

# %%
# Creating groupby for weekday & hour of taxi pickups(size)

taxi_two_weekday_hours = taxi_two.groupby(['taxi_two_weekday','taxi_two_hour'], as_index = False).size()

# %%
# Updated groupby for weekday,hours of uber pickups represented by 'size'

taxi_two_weekday_hours
# Out:
#     taxi_two_weekday  taxi_two_hour   size
# 0             Friday              0  51003
# 1             Friday              1  37056
# 2             Friday              2  25158
# 3             Friday              3  17163
# 4             Friday              4  14727
# ..               ...            ...    ...
# 163        Wednesday             19  72726
# 164        Wednesday             20  64494
# 165        Wednesday             21  61147
# 166        Wednesday             22  57228
# 167        Wednesday             23  50226
#
# [168 rows x 3 columns]

# %% [markdown]
# # Data Visualization of Uber Trends from January - June 2015 (Q1-Q2)

# %%
# Creating countplot for visualization of customers per month while readjusting month order for readability

sns.countplot(data = df,x='month',palette = 'Set2', order=month_order)

# Renaming x,y and title

plt.xlabel("Months")
plt.ylabel("Uber Pickups")
plt.title('Months of Uber Pickups 2015(Q1-Q2)')

# Displaying the countplot
plt.show()

# %%
# Creating barplot for visualization of customers per month on specific weekdays 

ax = pivot_sorted.plot(kind = 'bar',figsize=(10,4),title='Months and Weekdays of Uber Pickups 2015(Q1-Q2)')

# Renaming x,y and legend title

ax.set_xlabel("Months of Weekdays")
ax.set_ylabel("Uber Pickups")
plt.legend(title='Weekday')

# Moving the legend for visibility

sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
# Creating pointplot for visualization of customers per hour on weekdays(hue) with weekday_hours dataframe(groupby)

# Setting a figure size while adjusting it to become a subplot

fig, ax = plt.subplots(figsize=(10,6),dpi = 150)

# Set title of the visualization
ax.set_title('Hours & Weekdays of Uber Pickups 2015(Q1-Q2)')

# Creating the pointplot while renaming x and y label
sns.pointplot(data = weekday_hours,x='hours',y='size',hue = 'weekday',palette = 'Set2',hue_order =weekday_order).set(xlabel = 'Hours', ylabel = 'Uber Pickups')

# Customizing and adjusting the grid/legend
plt.grid(True)
plt.legend(title='Weekday')
plt.tight_layout()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# # Data Visualization of NYC Taxi Trends from January - June 2015 (Q1-Q2)

# %%
# Creating countplot for visualization of customers per month while readjusting month order for readability

sns.countplot(data = taxi,x='taxi_month',palette = 'Set2', order=month_order)

# Renaming x,y and title

plt.xlabel("Months")
plt.ylabel("Taxi Pickups")
plt.title('Months of Taxi Pickups 2015(Q1-Q2)')

# Displaying the countplot
plt.show()

# %% [markdown]
# In the analysis of Uber and taxi pickups during the first two quarters of 2015, a consistent trend is observed between the two transportation modes. However, noteworthy distinctions emerge in the months of: March, April, and May, where Uber exhibits an uptick in pickups compared to taxis. Conversely, June experiences a marginal decrease in Uber pickups compared to taxis. June emerges as the peak month for Uber pickups, whereas May claims this distinction for taxi pickups.

# %%
# Creating barplot for visualization of customers per month on specific weekdays 

ax = taxi_pivot_sorted.plot(kind = 'bar',figsize=(10,4),title='Months and Weekdays of Taxi Pickups 2015(Q1-Q2)')

# Renaming x,y and legend title

ax.set_xlabel("Months of Weekdays")
ax.set_ylabel("Taxi Pickups")
plt.legend(title='Weekday')

# Moving the legend for visibility

sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# Likewise, in this bar plot analysis, the similarity between taxi and Uber pickups is apparent, with a distinction in the dominance of Saturdays throughout every month of Q1-Q2 for taxi pickups. Uber, on the other hand, exhibits a diverse pattern with varying dominant weekdays, while the distinct prominence of Thursdays in taxi pickups is apparent.

# %%
# Creating pointplot for visualization of customers per hour on weekdays(hue) with weekday_hours dataframe(groupby)

# Setting a figure size while adjusting it to become a subplot

fig, ax = plt.subplots(figsize=(10,6),dpi = 150)

# Set title of the visualization
ax.set_title('Hours & Weekdays of Taxi Pickups 2015(Q1-Q2)')

# Creating the pointplot while renaming x and y label
sns.pointplot(data = taxi_weekday_hours,x='taxi_hour',y='size',hue = 'taxi_weekday',palette = 'Set2',hue_order =weekday_order).set(xlabel = 'Hours', ylabel = 'Taxi Pickups')

# Customizing and adjusting the grid/legend
plt.grid(True)
plt.legend(title='Weekday')
plt.tight_layout()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# In the analysis of Taxi Pickups, a distinct pattern emerges during the hours of 0-6, showcasing a sharp decline, followed by a rapid increase from 6 to 8. Subsequently, there is a steady decrease from 8 to 13, with an inrease during the hours of 13-18. The trend takes another dip from 18 to 23. An exception to this pattern is observed on weekdays, particularly on Friday and Saturday, where the hours 0-6 exhibit a similar decline but gradually increase throughout the day. Notably, these two weekdays stand out with the highest taxi pickups compared to other weekdays.
#
# Likewise, Uber Pickups follow a parallel trajectory, with a notable drop during 0-5, followed by an increase from 5 to 9. Subsequently, there is a decrease or stagnation from 9 to 13, followed by a resurgence from 13 to 18, and another decline from 18 to 23. Similar to the Taxi trend, Fridays and Saturdays deviate from the norm, maintaining a consistent pattern but with a decrease from 0 to 5 and a gradual increase throughout the day.

# %% [markdown]
# ## Data Visualization of Uber's aggregated trips (January-Febuary 2015)

# %%
# Creating boxplot for visualization of active vechicles per dispatching base number location

# Setting a figure size
plt.figure(figsize=(10, 6),dpi = 150)

# Creating the boxplot while adjusting it to become a subplot
ax = sns.boxplot(data=df_base_num, x='active_vehicles', y='dispatching_base_number')

# Renaming x,y and title
plt.title('Active Vehicles per Dispatching Base')
plt.xlabel('Count of Active Vehicles')
plt.ylabel('Dispatching Base Number')

# Setting x label limit to reduce white space
ax.set_xlim(left=0)

# Resizing and displaying the boxplot
plt.tight_layout()
plt.show()

# %%
df_base_num
# Out:
#     dispatching_base_number       date  active_vehicles  trips
# 0                    B02512   1/1/2015              190   1132
# 1                    B02765   1/1/2015              225   1765
# 2                    B02764   1/1/2015             3427  29421
# 3                    B02682   1/1/2015              945   7679
# 4                    B02617   1/1/2015             1228   9537
# ..                      ...        ...              ...    ...
# 349                  B02764  2/28/2015             3952  39812
# 350                  B02617  2/28/2015             1372  14022
# 351                  B02682  2/28/2015             1386  14472
# 352                  B02512  2/28/2015              230   1803
# 353                  B02765  2/28/2015              747   7753
#
# [354 rows x 4 columns]

# %% [markdown]
# ## Data Visualization of Uber Trends from April-September 2014 (Q2-Q3)

# %%
# Creating countplot for visualization of customers per month while readjusting month order for readability

sns.countplot(data = combined_df,x='month',palette = 'Set2', order=month_order2)

# Renaming x,y and title

plt.xlabel("Months")
plt.ylabel("Uber Pickups")
plt.title('Months of Uber Pickups(Q2-Q3)')

# Displaying the countplot
plt.show()

# %%
# Creating barplot for visualization of customers per month on specific weekdays 

ax = pivot_sorted2.plot(kind = 'bar',figsize=(10,4),title='Months and Weekdays of Uber Pickups(Q2-Q3)')

# Renaming x,y and legend title

ax.set_xlabel("Months of Weekdays")
ax.set_ylabel("Uber Pickups")
plt.legend(title='Weekday')

# Moving the legend for visibility

sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
# Creating pointplot for visualization of customers per hour on weekdays(hue) with weekday_hours2 dataframe(groupby)

# Setting a figure size while adjusting it to become a subplot

fig, ax = plt.subplots(figsize=(10,6),dpi = 150)

# Set title of the visualization
ax.set_title('Hours & Weekdays of Uber Pickups(Q2-Q3)')

# Creating the pointplot while renaming x and y label
sns.pointplot(data = weekday_hours2,x='hour',y='size',hue = 'weekday',palette = 'Set2',hue_order =weekday_order).set(xlabel = 'Hours', ylabel = 'Uber Pickups')

# Customizing and adjusting the grid/legend
plt.grid(True)
plt.legend(title='Weekday')
plt.tight_layout()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# ## Data Visualization of NYC Taxi Trends from April-September 2014 (Q2-Q3)

# %%
# Creating countplot for visualization of customers per month while readjusting month order for readability

sns.countplot(data = taxi_two,x='taxi_two_month',palette = 'Set2', order=month_order2)

# Renaming x,y and title

plt.xlabel("Months")
plt.ylabel("Taxi Pickups")
plt.title('Months of Taxi Pickups 2014(Q2-Q3)')

# Displaying the countplot
plt.show()

# %% [markdown]
# In the examination of Taxi Pickups during the second and third quarters of 2014, a consistent pattern is present within the distribution are evenly distributed throughout all months. There are no noticeable variations, and the taxi pickups maintain a relatively stable distribution across each month.
#
# Conversely, the analysis of Uber Pickups during the same period reveals a distinct trend. Across every month, Uber pickups exhibit a gradual increase from April to September, with September recording the highest number of pickups. This trend suggests a progressive growth in Uber pickups over the specified time frame, reaching its peak in the month of September.

# %%
# Creating barplot for visualization of customers per month on specific weekdays 

ax = taxi_two_pivot_sorted.plot(kind = 'bar',figsize=(10,4),title='Months and Weekdays of Taxi Pickups 2014(Q2-Q3)')

# Renaming x,y and legend title

ax.set_xlabel("Months of Weekdays")
ax.set_ylabel("Taxi Pickups")
plt.legend(title='Weekday')

# Moving the legend for visibility

sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %%
# Creating pointplot for visualization of customers per hour on weekdays(hue) with weekday_hours dataframe(groupby)

# Setting a figure size while adjusting it to become a subplot

fig, ax = plt.subplots(figsize=(10,6),dpi = 150)

# Set title of the visualization
ax.set_title('Hours & Weekdays of Taxi Pickups 2014(Q2-Q3)')

# Creating the pointplot while renaming x and y label
sns.pointplot(data = taxi_two_weekday_hours,x='taxi_two_hour',y='size',hue = 'taxi_two_weekday',palette = 'Set2',hue_order =weekday_order).set(xlabel = 'Hours', ylabel = 'Taxi Pickups')

# Customizing and adjusting the grid/legend
plt.grid(True)
plt.legend(title='Weekday')
plt.tight_layout()
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# ## Creating an unstacked groupby  for Uber Pickups 2014(Q2-Q3)

# %%
# Creating a unstacked groupby by day & hour by size()(Uber 2014(Q2-Q3))

combined_df_unstacked = combined_df.groupby(['day','hour']).size().unstack()

# %%
# Renaming columns/index and styling background for readability

combined_df_unstacked = combined_df_unstacked.rename_axis(columns='Hour',index = 'Day')
combined_df_unstacked.style.background_gradient()
# Out:
# <style type="text/css">
# #T_0c06f_row0_col0, #T_0c06f_row8_col23, #T_0c06f_row23_col2 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_0c06f_row0_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_0c06f_row0_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_0c06f_row0_col3 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_0c06f_row0_col4, #T_0c06f_row0_col8 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_0c06f_row0_col5, #T_0c06f_row23_col3, #T_0c06f_row25_col0, #T_0c06f_row26_col7 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_0c06f_row0_col6, #T_0c06f_row8_col3, #T_0c06f_row12_col23, #T_0c06f_row20_col20 {
#   background-color: #76aad0;
#   color: #f1f1f1;
# }
# #T_0c06f_row0_col7, #T_0c06f_row0_col11, #T_0c06f_row12_col20, #T_0c06f_row20_col15 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_0c06f_row0_col9, #T_0c06f_row17_col22, #T_0c06f_row20_col21, #T_0c06f_row24_col20 {
# ...

# %% [markdown]
# ## Creating an unstacked groupby for NYC Taxi Pickups 2014(Q2-Q3)

# %%
# Creating a unstacked groupby by day & hour by size()(Taxi 2014(Q2-Q3))

taxi_combined_df_unstacked = taxi_two.groupby(['taxi_two_day','taxi_two_hour']).size().unstack()

# %%
# Renaming columns/index and styling background for readability

taxi_combined_df_unstacked = taxi_combined_df_unstacked.rename_axis(columns='Hour',index = 'Day')
taxi_combined_df_unstacked.style.background_gradient()
# Out:
# <style type="text/css">
# #T_c5c3d_row0_col0, #T_c5c3d_row23_col2, #T_c5c3d_row28_col5 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_c5c3d_row0_col1 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_c5c3d_row0_col2, #T_c5c3d_row3_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_c5c3d_row0_col3 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_c5c3d_row0_col4, #T_c5c3d_row24_col5 {
#   background-color: #b0c2de;
#   color: #000000;
# }
# #T_c5c3d_row0_col5, #T_c5c3d_row0_col23, #T_c5c3d_row13_col2, #T_c5c3d_row16_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_c5c3d_row0_col6, #T_c5c3d_row6_col14, #T_c5c3d_row10_col11, #T_c5c3d_row11_col9, #T_c5c3d_row12_col10, #T_c5c3d_row14_col12, #T_c5c3d_row16_col10, #T_c5c3d_row25_col19, #T_c5c3d_row28_col7 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# In exploring Uber's expansion within New York City, the analysis reveals pivotal insights into the changing dynamics of urban transportation. The data uncovered Uber's significant surge in the outer boroughs, indicating a notable influx in travel preferences. Furthermore, examining Uber's impact on rush-hour congestion unveiled intriguing patterns, highlighting varying degrees of influence throughout different times of the day.
#
# These findings underscore Uber's remarkable growth trajectory in New York City, showcasing its adaptive prowess and competitive edge within a tightly regulated urban transportation environment. As the city grapples with congestion concerns, comprehending the evolving role of innovative ride-sharing services like Uber stands as a crucial consideration for enhancing transportation efficiency and addressing the challenges of urban mobility.
